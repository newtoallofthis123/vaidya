# %%
from getpass import getpass
GOOGLE_API_KEY = getpass()
# Out:
#  ········

# %%
# %pip install langchain-community tqdm langchain-google-genai ipywidgets langchain-text-splitters lxml
# Out:
# Collecting langchain-community
#   Using cached langchain_community-0.3.18-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: tqdm in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (4.67.1)
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.0.11-py3-none-any.whl.metadata (3.6 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-text-splitters
#   Using cached langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# Collecting lxml
#   Using cached lxml-5.3.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting langchain-core<1.0.0,>=0.3.37 (from langchain-community)
#   Downloading langchain_core-0.3.40-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain<1.0.0,>=0.3.19 (from langchain-community)
#   Using cached langchain-0.3.19-py3-none-any.whl.metadata (7.9 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain-community)
#   Using cached SQLAlchemy-2.0.38-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: requests<3,>=2 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from langchain-community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.11.13-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting tenacity!=8.4.0,<10,>=8.1.0 (from langchain-community)
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting langsmith<0.4,>=0.1.125 (from langchain-community)
#   Downloading langsmith-0.3.11-py3-none-any.whl.metadata (14 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from langchain-community) (2.1.3)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.16 (from langchain-google-genai)
#   Downloading google_ai_generativelanguage-0.6.16-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pydantic<3,>=2 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from langchain-google-genai) (2.10.6)
# Requirement already satisfied: comm>=0.1.3 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipywidgets) (9.0.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.4.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached propcache-0.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai)
#   Using cached google_api_core-2.24.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai)
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai)
#   Using cached proto_plus-1.26.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.29.3)
# Requirement already satisfied: decorator in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.37->langchain-community)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.125->langchain-community)
#   Using cached orjson-3.10.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.4,>=0.1.125->langchain-community)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.125->langchain-community)
#   Using cached zstandard-0.23.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from pydantic<3,>=2->langchain-google-genai) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain-community)
#   Using cached greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai)
#   Using cached googleapis_common_protos-1.68.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.70.0)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai)
#   Using cached grpcio_status-1.70.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: anyio in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jsonpointer>=1.9 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.37->langchain-community) (3.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: executing>=1.2.0 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: sniffio>=1.1 in /home/noobscience/Projects/vaidya/venv/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Using cached langchain_community-0.3.18-py3-none-any.whl (2.5 MB)
# Downloading langchain_google_genai-2.0.11-py3-none-any.whl (39 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached langchain_text_splitters-0.3.6-py3-none-any.whl (31 kB)
# Using cached lxml-5.3.1-cp312-cp312-manylinux_2_28_x86_64.whl (5.0 MB)
# Downloading aiohttp-3.11.13-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.2 MB/s eta 0:00:005.0 MB/s eta 0:00:01
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_ai_generativelanguage-0.6.16-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.6 MB/s eta 0:00:00
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached langchain-0.3.19-py3-none-any.whl (1.0 MB)
# Downloading langchain_core-0.3.40-py3-none-any.whl (414 kB)
# Downloading langsmith-0.3.11-py3-none-any.whl (335 kB)
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Using cached SQLAlchemy-2.0.38-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Using cached aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
# Using cached google_api_core-2.24.1-py3-none-any.whl (160 kB)
# Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Using cached greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
# Using cached orjson-3.10.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
# Using cached propcache-0.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (243 kB)
# Using cached proto_plus-1.26.0-py3-none-any.whl (50 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (336 kB)
# Using cached zstandard-0.23.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached googleapis_common_protos-1.68.0-py2.py3-none-any.whl (164 kB)
# Using cached grpcio_status-1.70.0-py3-none-any.whl (14 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: filetype, zstandard, widgetsnbextension, tenacity, pyasn1, proto-plus, propcache, orjson, mypy-extensions, multidict, marshmallow, lxml, jupyterlab-widgets, jsonpatch, httpx-sse, greenlet, googleapis-common-protos, frozenlist, cachetools, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, rsa, requests-toolbelt, pyasn1-modules, grpcio-status, aiosignal, pydantic-settings, langsmith, ipywidgets, google-auth, dataclasses-json, aiohttp, langchain-core, google-api-core, langchain-text-splitters, langchain, google-ai-generativelanguage, langchain-google-genai, langchain-community
# Successfully installed SQLAlchemy-2.0.38 aiohappyeyeballs-2.4.6 aiohttp-3.11.13 aiosignal-1.3.2 cachetools-5.5.2 dataclasses-json-0.6.7 filetype-1.2.0 frozenlist-1.5.0 google-ai-generativelanguage-0.6.16 google-api-core-2.24.1 google-auth-2.38.0 googleapis-common-protos-1.68.0 greenlet-3.1.1 grpcio-status-1.70.0 httpx-sse-0.4.0 ipywidgets-8.1.5 jsonpatch-1.33 jupyterlab-widgets-3.0.13 langchain-0.3.19 langchain-community-0.3.18 langchain-core-0.3.40 langchain-google-genai-2.0.11 langchain-text-splitters-0.3.6 langsmith-0.3.11 lxml-5.3.1 marshmallow-3.26.1 multidict-6.1.0 mypy-extensions-1.0.0 orjson-3.10.15 propcache-0.3.0 proto-plus-1.26.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-settings-2.8.1 requests-toolbelt-1.0.0 rsa-4.9 tenacity-9.0.0 typing-inspect-0.9.0 widgetsnbextension-4.0.13 yarl-1.18.3 zstandard-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004", google_api_key=GOOGLE_API_KEY)

# %%
from pydantic import BaseModel, ValidationError, Field
from typing import List, Dict, Any, Set

class Problem(BaseModel):
    name: str
    duration: str
    description: str


class PatientSchema(BaseModel):
    name: str = Field(..., description="Patient's name")
    age: int = Field(..., description="Patient's age")
    gender: str = Field(..., description="Patient's gender")
    address: str = Field(..., description="Patient's address")
    identity: str = Field(..., description="Patient's identity document")
    phone: str = Field(..., description="Patient's phone number")
    problems: List[Problem] = Field(..., description="List of patient's problems")
    conditions: List[Any] = Field(default=[], description="List of patient's conditions")
    description: str = Field(..., description="AI-generated description")
    recommended_doctor: str = Field(..., description="AI-generated doctor recommendation")

# %%
def get_missing_fields(data: Dict[str, Any], model = PatientSchema) -> Set[str]:
    try:
        model.model_validate(data)
        return set()
    except ValidationError as e:
        missing_fields = set()
        for error in e.errors():
            if error["type"] == "missing":
                missing_fields.add(error["loc"][0])
        return missing_fields

# %%
INCOMPLETE_JSON_SCHEMA = {
        "name": "Rani Sharma",
        "gender": "Female",
        "address": "Udaipur",
    }
missing = get_missing_fields(INCOMPLETE_JSON_SCHEMA)
print(f"Missing fields: {missing}")
# Out:
# Missing fields: {'description', 'identity', 'recommended_doctor', 'age', 'phone', 'problems'}

# %%
from langchain_core.prompts import ChatPromptTemplate, FewShotChatMessagePromptTemplate

examples=[ {"input": "Hello, my name is Ishan. I am living here in Hyderabad and I am suffering from fever, headache, and cold. I also have diabetes. This is missing the age field.",
            "output": """
{{
    "think": "First, I will extract the information from the initial sentence.",
    "info": {{
      "name": "Ishan",
      "age": "",
      "gender": "Male",
      "address": "Hyderabad",
      "identity": "",
      "phone": "",
      "problems": [
        {{
          "name": "fever",
          "duration": "",
          "description": "High fever"
        }},
        {{
          "name": "headache",
          "duration": "",
          "description": "Headache localized in the forehead"
        }},
        {{
          "name": "cold",
          "duration": "",
          "description": "",
        }}
      ],
      "conditions": ["diabetes"],
      "description": "[AI GENERATED] A male patient presenting with fever, headache, and cold symptoms, with a known diagnosis of diabetes.",
      "recommended_doctor": "[AI GENERATED] General Physician or Infectious Disease Specialist",
    }},
    "next_question": "What is your age?"
}}

        """, "field": "age"
          }]

# %%
example_prompt = ChatPromptTemplate.from_messages(
[('human', 'This is one example: {input}'), ('ai', '{output}')]
)

few_shot_prompt = FewShotChatMessagePromptTemplate(
    examples=examples,
    example_prompt=example_prompt,
)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
"""You are an information extraction model for electronic medical records. 
Your task is to extract relevant medical and personal information from a given sentence and then interactively ask questions to fill in any missing fields. 
Always follow these rules:
1. First, extract as much information as possible from the initial sentence.
2. Identify missing fields and ask the user questions to fill them in, one at a time.
3. Ask questions in a polite and helpful manner.
4. Continue asking questions until all fields are filled or the user declines to answer.
5. Do not assume or hallucinate information not present in the sentence or user responses.
6. Format the output as follows:

{{
    "think": "[Your thought process and explanations]",
    "info": {{
      "name": "extracted name",
      "age": "extracted age",
      "gender": "extracted or inferred gender",
      "address": "extracted address",
      "identity": "extracted identity",
      "phone": "extracted phone number",
      "problems": [
        {{
          "name": "symptom name",
          "duration": "duration of symptom",
          "description": "description regarding the symptom"
        }}
      ],
      "conditions": ["list of pre-existing conditions"],
      "description": "[AI GENERATED] Medically sounding description",
      "recommended_doctor": "[AI GENERATED] Suggested medical specialty"
    }},
    "next_question": "[Your next question]"
}}

Example interaction:

Initial input: "Hello, my name is Ishan. I am living here in Hyderabad and I am suffering from fever, headache, and cold. I also have diabetes."

{{
    "think": "First, I will extract the information from the initial sentence.",
    "info": {{
      "name": "Ishan",
      "age": "",
      "gender": "Male",
      "address": "Hyderabad",
      "identity": "",
      "phone": "",
      "problems": [
        {{
          "name": "fever",
          "duration": "",
          "description": "High fever"
        }},
        {{
          "name": "headache",
          "duration": "",
          "description": "Headache localized in the forehead"
        }},
        {{
          "name": "cold",
          "duration": "",
          "description": "",
        }}
      ],
      "conditions": ["diabetes"],
      "description": "[AI GENERATED] A male patient presenting with fever, headache, and cold symptoms, with a known diagnosis of diabetes.",
      "recommended_doctor": "[AI GENERATED] General Physician or Infectious Disease Specialist",
    }},
    "analysis": "The following fields are missing: age, phone, symptom description, and identity.",
    "next_question": "Please share your age"
}}

Now process this [INPUT_SENTENCE]
"""
        ),
        ("human", "{text} \n This is the current form: {form}"),
    ]
)

# %%
import json

example_prompt = prompt.invoke({"text": "hey! I am Ishan! A student from Hyderabad", "form": json.dumps({})})

for message in example_prompt.messages:
    print(f"{message.type}: {message}")
# Out:
# system: content='You are an information extraction model for electronic medical records. \nYour task is to extract relevant medical and personal information from a given sentence and then interactively ask questions to fill in any missing fields. \nAlways follow these rules:\n1. First, extract as much information as possible from the initial sentence.\n2. Identify missing fields and ask the user questions to fill them in, one at a time.\n3. Ask questions in a polite and helpful manner.\n4. Continue asking questions until all fields are filled or the user declines to answer.\n5. Do not assume or hallucinate information not present in the sentence or user responses.\n6. Format the output as follows:\n\n{\n    "think": "[Your thought process and explanations]",\n    "info": {\n      "name": "extracted name",\n      "age": "extracted age",\n      "gender": "extracted or inferred gender",\n      "address": "extracted address",\n      "identity": "extracted identity",\n      "phone": "extracted phone number",\n      "problems": [\n        {\n          "name": "symptom name",\n          "duration": "duration of symptom",\n          "description": "description regarding the symptom"\n        }\n      ],\n      "conditions": ["list of pre-existing conditions"],\n      "description": "[AI GENERATED] Medically sounding description",\n      "recommended_doctor": "[AI GENERATED] Suggested medical specialty"\n    },\n    "next_question": "[Your next question]"\n}\n\nExample interaction:\n\nInitial input: "Hello, my name is Ishan. I am living here in Hyderabad and I am suffering from fever, headache, and cold. I also have diabetes."\n\n{\n    "think": "First, I will extract the information from the initial sentence.",\n    "info": {\n      "name": "Ishan",\n      "age": "",\n      "gender": "Male",\n      "address": "Hyderabad",\n      "identity": "",\n      "phone": "",\n      "problems": [\n        {\n          "name": "fever",\n          "duration": "",\n          "description": "High fever"\n        },\n        {\n          "name": "headache",\n          "duration": "",\n          "description": "Headache localized in the forehead"\n        },\n        {\n          "name": "cold",\n          "duration": "",\n          "description": "",\n        }\n      ],\n      "conditions": ["diabetes"],\n      "description": "[AI GENERATED] A male patient presenting with fever, headache, and cold symptoms, with a known diagnosis of diabetes.",\n      "recommended_doctor": "[AI GENERATED] General Physician or Infectious Disease Specialist",\n    },\n    "analysis": "The following fields are missing: age, phone, symptom description, and identity.",\n    "next_question": "Please share your age"\n}\n\nNow process this [INPUT_SENTENCE]\n' additional_kwargs={} response_metadata={}
# human: content='hey! I am Ishan! A student from Hyderabad \n This is the current form: {}' additional_kwargs={} response_metadata={}

# %%
from langchain_core.globals import set_llm_cache
from langchain_google_genai import GoogleGenerativeAI
from langchain_core.caches import InMemoryCache

llm = GoogleGenerativeAI(model="gemini-2.0-flash", google_api_key=GOOGLE_API_KEY)

set_llm_cache(InMemoryCache())

# %%
print(llm.invoke(prompt.invoke({"text": "hey! I am Ishan! A student from Hyderabad", "form": json.dumps({})})))
# Out:
# ```json
# {
#     "think": "Okay, I will extract the available information from the input sentence and then formulate a question to gather more details.",
#     "info": {
#       "name": "Ishan",
#       "age": "",
#       "gender": "Male",
#       "address": "Hyderabad",
#       "identity": "student",
#       "phone": "",
#       "problems": [],
#       "conditions": [],
#       "description": "[AI GENERATED] A male student from Hyderabad.",
#       "recommended_doctor": "[AI GENERATED] General Practitioner"
#     },
#     "next_question": "Hi Ishan, nice to meet you! How old are you?"
# }
# ```

# %%
x = {
    "think": "I will extract the information from the user's response and update the JSON with the provided details.",
    "info": {
      "name": "Ishan",
      "age": "22",
      "gender": "Male",
      "address": "Hyderabad",
      "identity": "student",
      "phone": "9014678452",
      "problems": [],
      "conditions": [],
      "description": "[AI GENERATED] A 22-year-old male student from Hyderabad.",
      "recommended_doctor": "[AI GENERATED] General Practitioner"
    },
    "next_question": "Could you please describe the problems you are facing?"
}
curr = json.dumps(x)
print(llm.invoke(prompt.invoke({"text": "I am facing headache and stomach pain since eating biryani yesterday!", "form": curr})))
# Out:
# Okay, I understand. I will continue the interaction based on the provided context.
#
# **Current state:**
#
# ```json
# {
#     "think": "I will extract the information from the user's response and update the JSON with the provided details.",
#     "info": {
#         "name": "Ishan",
#         "age": "22",
#         "gender": "Male",
#         "address": "Hyderabad",
#         "identity": "student",
#         "phone": "9014678452",
#         "problems": [],
#         "conditions": [],
#         "description": "[AI GENERATED] A 22-year-old male student from Hyderabad.",
#         "recommended_doctor": "[AI GENERATED] General Practitioner"
#     },
#     "next_question": "Could you please describe the problems you are facing?"
# }
# ```
#
# **User Input:** I am facing headache and stomach pain since eating biryani yesterday!
#
# ```json
# {
#     "think": "I will extract the information from the user's response and update the JSON with the provided details.",
#     "info": {
#         "name": "Ishan",
#         "age": "22",
#         "gender": "Male",
#         "address": "Hyderabad",
#         "identity": "student",
#         "phone": "9014678452",
#         "problems": [
#             {
#                 "name": "headache",
#                 "duration": "since yesterday",
#                 "description": ""
#             },
#             {
#                 "name": "stomach pain",
#                 "duration": "since yesterday",
#                 "description": ""
#             }
#         ],
#         "conditions": [],
#         "description": "[AI GENERATED] A 22-year-old male student from Hyderabad presenting with headache and stomach pain since yesterday, potentially related to food consumption.",
#         "recommended_doctor": "[AI GENERATED] General Practitioner or Gastroenterologist"
#     },
#     "next_question": "Can you please describe the nature of your headache? For example, is it throbbing, constant, or sharp?"
# }
# ```

# %%
from typing_extensions import TypedDict


class State(TypedDict):
    question: str
    answer: str
